# %%
import random

from collections import deque

import numpy as np
import tensorflow as tf
import keras.backend as K

from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.optimizers import Adam

import pandas as pd
import math

# %%
def huber_loss(y_true, y_pred, clip_delta=1.0):
    #Huber loss - Custom Loss Function for Q Learning
    error = y_true - y_pred
    cond = K.abs(error) <= clip_delta
    squared_loss = 0.5 * K.square(error)
    quadratic_loss = 0.5 * K.square(clip_delta) + clip_delta * (K.abs(error) - clip_delta)
    return K.mean(tf.where(cond, squared_loss, quadratic_loss))

# %%
def get_state(data, t, n_days): # here t is the current t and n is the window size
    d = t - n_days + 1 # if we have n previos day records they are stored else the first day record is assumed to be the record of the previous days
    if d >= 0:
      block = data[d: t + 1] 
    else:
      block = -d * [data[0]] + data[0: t + 1]
    #block is now the data for the last window_size days
    res = []
    for i in range(n_days - 1):
        res.append((block[i + 1] - block[i]))
     #res tells us the relation of the data from the last day
    return np.array([res]) #Returns an n-day state representation ending at time t

# %%
def train_model(agent, episode, data,init_xbt, ep_count=100, batch_size=32, window_size=10):
    total_profit = 0
    data_length = len(data) - 1 #number of entries
    format_position = lambda price: ('-$' if price < 0 else '+$') + '{0:.2f}'.format(abs(price))
    agent.inventory = []#empty inventory
    avg_loss = []

    state = get_state(data, 0, window_size + 1) # state is the vector with previos window size day records and their relation  we start with t = 0
    
    print('Episode {}/{}'.format(episode, ep_count))

    for t in range(data_length):# for loop for varying time stamp        
        reward = 0
        next_state = get_state(data, t + 1, window_size + 1)# get data for t+1 state

        action = agent.act(state) # class method to decide the action to take (buy,sell,sit )

        # BUY
        if action == 1:
            print("Bought 1 XBT at price :{}".format(format_position(data[t])))
            init_xbt = init_xbt + 1  #We buy 1 unit of the coin
            agent.inventory.append(data[t])

        # SELL
        elif action == 2 and len(agent.inventory) > 0:
            bought_price = agent.inventory.pop(0)
            init_xbt = init_xbt / 2 # We sell half the coins we have at time t
            delta = data[t] - bought_price
            reward = delta# positive reward if seling at time t price is higher than bought price 
            print("Sold {} XBT at price :{}   || Profit : {}".format(init_xbt,format_position(data[t]),format_position(delta*init_xbt)))
            total_profit += delta*(init_xbt)  # keep a track of total profit

        # HOLD
        else:
            pass

        done = (t == data_length - 1)#only when we have traersed to all the days in the dataset
        agent.remember(state, action, reward, next_state, done)#store the datain memory

        if len(agent.memory) > batch_size:
            loss = agent.train_experience(batch_size) #train the model on the past experience
            avg_loss.append(loss) # track the loss in the the training

        state = next_state # now the current state will be the next state getState(data, t + 1, window_size + 1) i.e data for t+1 day

    agent.save(episode) # save the model for each episode
    print("Total Profit : ",total_profit) #print total profit
    return (episode, ep_count, total_profit, np.mean(np.array(avg_loss)))

# %%
def evaluate_model(agent, data, window_size,init_xbt,init_amt):
    total_profit = 0
    data_length = len(data) - 1

    history = []
    agent.inventory = []
    format_position = lambda price: ('-$' if price < 0 else '+$') + '{0:.2f}'.format(abs(price))

    state = get_state(data, 0, window_size + 1)# state is the vector with previos window size day records and their relation  we start with t = 0

    for t in range(data_length):        
        reward = 0
        next_state = get_state(data, t + 1, window_size + 1)
        
        action = agent.act(state, is_eval=True)# select an action

        # BUY
        if action == 1 and init_amt > 0:
            print("Bought 1 XBT at price :{}".format(format_position(data[t])))
            init_xbt = init_xbt + 1 #We buy 1 bitcoin at that rate
            init_amt -= data[t] # anount deducted from balance
            agent.inventory.append(data[t])
            
            history.append((data[t], "BUY"))

        # SELL
        elif action == 2 and len(agent.inventory) > 0:
            bought_price = min(agent.inventory)  # We sell the bitcoin first that we bought at the lowest price
            agent.inventory.pop(np.argmin(agent.inventory))
            init_xbt = init_xbt / 2 # Whenever we have to sell we sell half the coin we own at that moment
            delta = data[t] - bought_price
            reward = delta 
            print("Sold {} XBT at price :{}   || Profit : {}".format(init_xbt,format_position(data[t]),format_position(delta*init_xbt)))
            total_profit += delta*(init_xbt) # Track of total profit
            init_amt += data[t]*(init_xbt) # porfit amount is added in the account balance

            history.append((data[t], "SELL"))
        # HOLD
        else:
            print("Holding") 
            history.append((data[t], "HOLD"))

        done = (t == data_length - 1) # done true if traversed through all data
        agent.memory.append((state, action, reward, next_state, done)) # store this information in memory of the agent

        state = next_state 
        if done:
            return total_profit,init_amt,init_xbt,history

# %%
def show_eval_result(model_name, profit,amt,init_amt,xbt,init_xbt):
    format_position = lambda price: ('-$' if price < 0 else '+$') + '{0:.2f}'.format(abs(price))
    print("\nSUMMARY:")
    print('Initial Bank Balance: {}'.format(format_position(init_amt)))
    print('Initial Bitcoins owned(1%): {}'.format(init_xbt))
    print('\n')
    print('Final Bank Balace: {}'.format(format_position(amt)))
    print('Final Bitcoins owned: {}'.format(xbt))
    print('\nTotal Profit: {}'.format(format_position(profit)))
    print('(Trained Model  :{})'.format(model_name))

# %%
class Agent:

    def __init__(self, state_size, model_name=None):
      
        self.state_size = state_size    	# normalized previous days
        self.action_size = 3           		# [sit, buy, sell]
        self.model_name = model_name
        self.inventory = []
        self.memory = deque(maxlen=10000)

        self.model_name = model_name
        self.gamma = 0.95 # affinity for long term reward
        self.epsilon = 1.0  # for epsilon greedy algorithm
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.loss = huber_loss
        self.custom_objects = {"huber_loss": huber_loss}  # important for loading the model from memory
        self.optimizer = Adam(lr=self.learning_rate)

        if self.model_name is not None:
            self.model = self.load()
        else:
            self.model = self._model()

    def _model(self):
        model = Sequential()
        model.add(Dense(units=128, activation="relu", input_dim=self.state_size))
        model.add(Dense(units=256, activation="relu"))
        model.add(Dense(units=256, activation="relu"))
        model.add(Dense(units=128, activation="relu"))
        model.add(Dense(units=self.action_size))

        model.compile(loss=self.loss, optimizer=self.optimizer)
        return model

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))# Add the data in memory of the agent

    def act(self, state, is_eval=False):
        if not is_eval and random.random() <= self.epsilon:#if we are training the model
            return random.randrange(self.action_size)# take random action in order to diversify experience at the beginning

        action_probs = self.model.predict(state)# if we are predicting we ask the model to predict the value of all possible actions
        #print("action_probs",action_probs)
        return np.argmax(action_probs[0])# we take the option with highest probabilty predicted by the model

    def train_experience(self, batch_size):#Train on previous experiences in memory
      
        mini_batch = random.sample(self.memory, batch_size)
        X_train, y_train = [], []

        for state, action, reward, next_state, done in mini_batch:
            if done:
                target = reward #reward of state action
            else:
              # approximate deep q-learning equation
              # Updating network weights using the Bellman Equation
              q_values = self.model.predict(state)# estimate q-values based on current state
              q_values[0][action] = target# update the target for current action based on discounted reward

              X_train.append(state[0])
              y_train.append(q_values[0])

 
        #parameters based on huber loss gradient
        loss = self.model.fit(
            np.array(X_train), np.array(y_train),
            epochs=1, verbose=0
        ).history["loss"][0]

        # as the training goes on we want the agent to make less random and more optimal decisions
        if self.epsilon > self.epsilon_min:#by this in each batch we reduce the epsilon value and when the model is trained few times we will  start predict action from model instead of an random no in method act 
            self.epsilon *= self.epsilon_decay

        return loss

    def save(self, episode):
        self.model.save("model{}".format(episode)) # save the trained model

    def load(self):
        return load_model(self.model_name, custom_objects=self.custom_objects) # load an existing trained model

# %%
def get_stock_data(stock_file):
    df = pd.read_csv(stock_file + '.csv')
    return list(df['Open']),df['Volume_(BTC)'][0] #Consider Opening price at each minute and initial bitcoint the agent will have
# We assume that the agent bys and sell the bitcoin on the opening price of the minute as sata is of 1 min interval

# %%
# For training of model
train_stock = input("Enter the name of stock file")

window_size = int(input("Enter window size")) # window size represents the number of previous days record model considers to take action

batch_size = 32
ep_count = int(input("Enter episode count"))# similar to epoch
model_name = ""

agent = Agent(window_size) #Create a object of the class Agent
train_data,init_xbt = get_stock_data(train_stock) #get vectorised format of csv data and initial bitcoin (1%)

for episode in range(1, ep_count + 1):  # in one  episode we traverse trough the data 1 time
  train_result = train_model(agent, episode, train_data,init_xbt, ep_count=ep_count,batch_size=batch_size, window_size=window_size)
# Out:
# Enter the name of stock filefinal
# Enter window size10
# Enter episode count1
# Episode 1/1
# Bought 1 XBT at price :+$4.39
# Sold 0.727790435 XBT at price :+$4.39   || Profit : 0.0
# Bought 1 XBT at price :+$4.84
# Sold 0.8638952175 XBT at price :+$5.00   || Profit : 0.13822323480000012
# Bought 1 XBT at price :+$5.14
# Bought 1 XBT at price :+$5.29
# Sold 1.43194760875 XBT at price :+$4.93   || Profit : -0.30070899783749994
# Sold 0.715973804375 XBT at price :+$4.93   || Profit : -0.25775056957500025
# Bought 1 XBT at price :+$5.36
# Bought 1 XBT at price :+$5.37
# Sold 1.3579869021875 XBT at price :+$5.72   || Profit : 0.4888752847874992
# Bought 1 XBT at price :+$5.75
# Sold 1.17899345109375 XBT at price :+$5.75   || Profit : 0.4480175114156249
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Sold 1.589496725546875 XBT at price :+$6.46   || Profit : 1.1285426751382812
# Sold 0.7947483627734375 XBT at price :+$6.43   || Profit : 0.3417417959925779
# Sold 0.39737418138671876 XBT at price :+$6.44   || Profit : 0.1748446398101564
# Bought 1 XBT at price :+$6.43
# Bought 1 XBT at price :+$6.47
# Bought 1 XBT at price :+$6.65
# Bought 1 XBT at price :+$6.65
# Bought 1 XBT at price :+$6.65
# Sold 2.698687090693359 XBT at price :+$6.69   || Profit : 0.7016586435802752
# Bought 1 XBT at price :+$6.80
# Bought 1 XBT at price :+$6.76
# Sold 2.3493435453466796 XBT at price :+$6.49   || Profit : 0.04698687090693467
# Sold 1.1746717726733398 XBT at price :+$6.40   || Profit : -0.29366794316833494
# Bought 1 XBT at price :+$6.40
# Bought 1 XBT at price :+$6.40
# Bought 1 XBT at price :+$6.40
# Bought 1 XBT at price :+$6.30
# Bought 1 XBT at price :+$6.20
# Bought 1 XBT at price :+$6.00
# Sold 3.5873358863366698 XBT at price :+$6.80   || Profit : 0.5381003829504986
# Bought 1 XBT at price :+$6.90
# Bought 1 XBT at price :+$7.00
# Bought 1 XBT at price :+$6.90
# Bought 1 XBT at price :+$6.90
# Bought 1 XBT at price :+$6.50
# Sold 4.293667943168335 XBT at price :+$6.50   || Profit : -0.6440501914752518
# Sold 2.1468339715841673 XBT at price :+$6.50   || Profit : -0.6440501914752498
# Sold 1.0734169857920837 XBT at price :+$6.60   || Profit : -0.17174671772673353
# Sold 0.5367084928960418 XBT at price :+$6.57   || Profit : 0.09124044379232707
# Sold 0.2683542464480209 XBT at price :+$6.60   || Profit : 0.05367084928960399
# Sold 0.13417712322401046 XBT at price :+$6.60   || Profit : 0.026835424644801997
# Bought 1 XBT at price :+$6.60
# Sold 0.5670885616120053 XBT at price :+$6.60   || Profit : 0.17012656848360147
# Sold 0.28354428080600264 XBT at price :+$6.60   || Profit : 0.1134177123224009
# Sold 0.14177214040300132 XBT at price :+$6.60   || Profit : 0.08506328424180074
# Sold 0.07088607020150066 XBT at price :+$6.60   || Profit : -0.02126582106045025
# Bought 1 XBT at price :+$6.60
# Bought 1 XBT at price :+$6.60
# Sold 1.0354430351007502 XBT at price :+$6.36   || Profit : -0.6626835424644798
# Bought 1 XBT at price :+$6.38
# Sold 1.017721517550375 XBT at price :+$6.49   || Profit : -0.41726582219565395
# Bought 1 XBT at price :+$6.48
# Sold 1.0088607587751874 XBT at price :+$6.23   || Profit : -0.6759367083793755
# Sold 0.5044303793875937 XBT at price :+$6.30   || Profit : -0.10088607587751883
# Sold 0.25221518969379686 XBT at price :+$6.24   || Profit : -0.09079746828976673
# Bought 1 XBT at price :+$6.24
# Sold 0.6261075948468984 XBT at price :+$6.24   || Profit : -0.22539873414488307
# Bought 1 XBT at price :+$6.24
# Sold 0.8130537974234492 XBT at price :+$6.40   || Profit : -0.16261075948468925
# Bought 1 XBT at price :+$6.54
# Sold 0.9065268987117245 XBT at price :+$6.54   || Profit : 0.14504430379387606
# Sold 0.45326344935586227 XBT at price :+$6.54   || Profit : 0.02719580696135156
# Bought 1 XBT at price :+$6.54
# Sold 0.7266317246779311 XBT at price :+$6.54   || Profit : 0.2179895174033792
# Sold 0.36331586233896557 XBT at price :+$6.54   || Profit : 0.1089947587016896
# Sold 0.18165793116948278 XBT at price :+$6.54   || Profit : 0.0
# Sold 0.09082896558474139 XBT at price :+$6.54   || Profit : 0.0
# Bought 1 XBT at price :+$6.55
# Bought 1 XBT at price :+$6.70
# Sold 1.0454144827923706 XBT at price :+$6.70   || Profit : 0.15681217241885595
# Sold 0.5227072413961853 XBT at price :+$6.70   || Profit : 0.0
# Bought 1 XBT at price :+$6.55
# Bought 1 XBT at price :+$7.10
# Sold 1.2613536206980926 XBT at price :+$7.10   || Profit : 0.6937444913839508
# Sold 0.6306768103490463 XBT at price :+$7.14   || Profit : 0.025227072413961875
# Bought 1 XBT at price :+$7.14
# Sold 0.8153384051745232 XBT at price :+$7.14   || Profit : 0.0
# Bought 1 XBT at price :+$7.14
# Sold 0.9076692025872616 XBT at price :+$7.14   || Profit : 0.0
# Bought 1 XBT at price :+$7.14
# Bought 1 XBT at price :+$7.14
# Bought 1 XBT at price :+$6.25
# Sold 1.9538346012936307 XBT at price :+$7.20   || Profit : 0.11723007607761882
# Sold 0.9769173006468154 XBT at price :+$7.20   || Profit : 0.05861503803880941
# Bought 1 XBT at price :+$7.20
# Bought 1 XBT at price :+$7.20
# Sold 1.4884586503234076 XBT at price :+$7.20   || Profit : 1.4140357178072376
# Bought 1 XBT at price :+$7.20
# Sold 1.2442293251617038 XBT at price :+$7.20   || Profit : 0.0
# Bought 1 XBT at price :+$7.20
# Sold 1.1221146625808518 XBT at price :+$7.20   || Profit : 0.0
# Bought 1 XBT at price :+$7.20
# Sold 1.061057331290426 XBT at price :+$7.20   || Profit : 0.0
# Bought 1 XBT at price :+$7.20
# Bought 1 XBT at price :+$7.20
# Sold 1.530528665645213 XBT at price :+$7.20   || Profit : 0.0
# Bought 1 XBT at price :+$7.20
# Bought 1 XBT at price :+$7.20
# Bought 1 XBT at price :+$7.20
# Bought 1 XBT at price :+$7.20
# Sold 2.7652643328226065 XBT at price :+$7.21   || Profit : 0.027652643328225476
# Sold 1.3826321664113033 XBT at price :+$7.22   || Profit : 0.027652643328225476
# Sold 0.6913160832056516 XBT at price :+$6.90   || Profit : -0.20739482496169537
# Sold 0.3456580416028258 XBT at price :+$7.00   || Profit : -0.06913160832056522
# Bought 1 XBT at price :+$7.00
# Sold 0.6728290208014129 XBT at price :+$7.00   || Profit : -0.13456580416028271
# Sold 0.33641451040070647 XBT at price :+$7.30   || Profit : 0.033641451040070526
# Bought 1 XBT at price :+$7.30
# Bought 1 XBT at price :+$7.25
# Bought 1 XBT at price :+$7.25
# Sold 1.6682072552003533 XBT at price :+$7.36   || Profit : 0.26691316083205674
# Sold 0.8341036276001766 XBT at price :+$6.80   || Profit : -0.1668207255200355
# Bought 1 XBT at price :+$6.70
# Bought 1 XBT at price :+$6.60
# Bought 1 XBT at price :+$6.51
# Bought 1 XBT at price :+$6.70
# Sold 2.4170518138000885 XBT at price :+$6.70   || Profit : -1.4502310882800522
# Bought 1 XBT at price :+$6.70
# Sold 1.7085259069000442 XBT at price :+$6.99   || Profit : -0.44421673579401116
# Sold 0.8542629534500221 XBT at price :+$7.00   || Profit : -0.21356573836250553
# Sold 0.42713147672501106 XBT at price :+$7.25   || Profit : 0.234922312198756
# Sold 0.21356573836250553 XBT at price :+$7.35   || Profit : 0.16017430377187913
# Sold 0.10678286918125277 XBT at price :+$7.36   || Profit : 0.0907654388040649
# Sold 0.05339143459062638 XBT at price :+$7.00   || Profit : 0.016017430377187905
# Sold 0.02669571729531319 XBT at price :+$6.90   || Profit : 0.005339143459062643
# Bought 1 XBT at price :+$6.90
# Sold 0.5133478586476566 XBT at price :+$6.90   || Profit : 0.0
# Bought 1 XBT at price :+$6.90
# Sold 0.7566739293238283 XBT at price :+$6.80   || Profit : -0.07566739293238323
# Bought 1 XBT at price :+$7.25
# Sold 0.8783369646619141 XBT at price :+$7.34   || Profit : 0.07905032681957215
# Bought 1 XBT at price :+$6.72
# Bought 1 XBT at price :+$6.60
# Sold 1.439168482330957 XBT at price :+$6.50   || Profit : -0.31661706611281015
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.30
# Sold 3.2195842411654785 XBT at price :+$6.30   || Profit : -0.965875272349643
# Bought 1 XBT at price :+$6.30
# Bought 1 XBT at price :+$7.15
# Sold 2.609792120582739 XBT at price :+$7.15   || Profit : 1.6963648783787812
# Sold 1.3048960602913695 XBT at price :+$7.15   || Profit : 0.8481824391893906
# Bought 1 XBT at price :+$7.15
# Sold 1.1524480301456848 XBT at price :+$7.15   || Profit : 0.7490912195946955
# Bought 1 XBT at price :+$6.20
# Bought 1 XBT at price :+$6.20
# Bought 1 XBT at price :+$6.20
# Bought 1 XBT at price :+$7.10
# Bought 1 XBT at price :+$7.10
# Sold 3.0762240150728424 XBT at price :+$7.10   || Profit : 1.8457344090437042
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Sold 2.538112007536421 XBT at price :+$6.90   || Profit : 1.522867204521854
# Bought 1 XBT at price :+$6.90
# Sold 1.7690560037682106 XBT at price :+$6.40   || Profit : 0.17690560037682201
# Sold 0.8845280018841053 XBT at price :+$6.20   || Profit : -0.8403016017899002
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Sold 1.4422640009420526 XBT at price :+$6.00   || Profit : -1.6586036010833611
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$5.99
# Sold 5.721132000471027 XBT at price :+$5.99   || Profit : -1.2014377200989155
# Sold 2.8605660002355133 XBT at price :+$5.99   || Profit : -0.6007188600494577
# Bought 1 XBT at price :+$5.99
# Bought 1 XBT at price :+$5.99
# Bought 1 XBT at price :+$5.99
# Bought 1 XBT at price :+$5.99
# Bought 1 XBT at price :+$5.99
# Sold 3.9302830001177567 XBT at price :+$5.99   || Profit : -0.8253594300247288
# Sold 1.9651415000588783 XBT at price :+$6.01   || Profit : -2.142004235064177
# Bought 1 XBT at price :+$6.02
# Sold 1.4825707500294392 XBT at price :+$6.10   || Profit : -1.4825707500294392
# Sold 0.7412853750147196 XBT at price :+$6.02   || Profit : -0.35581698000706574
# Sold 0.3706426875073598 XBT at price :+$6.50   || Profit : 0.0
# Sold 0.1853213437536799 XBT at price :+$6.50   || Profit : -0.07412853750147202
# Sold 0.09266067187683995 XBT at price :+$6.50   || Profit : 0.046330335938419974
# Sold 0.046330335938419974 XBT at price :+$6.50   || Profit : 0.023165167969209987
# Sold 0.023165167969209987 XBT at price :+$6.50   || Profit : 0.011582583984604993
# Sold 0.011582583984604993 XBT at price :+$6.50   || Profit : 0.005791291992302497
# Sold 0.005791291992302497 XBT at price :+$6.50   || Profit : 0.0028956459961512484
# Bought 1 XBT at price :+$6.50
# Sold 0.5028956459961512 XBT at price :+$6.50   || Profit : 0.2514478229980756
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$7.10
# Bought 1 XBT at price :+$5.52
# Bought 1 XBT at price :+$7.00
# Bought 1 XBT at price :+$6.19
# Bought 1 XBT at price :+$6.19
# Bought 1 XBT at price :+$6.09
# Sold 6.751447822998076 XBT at price :+$7.00   || Profit : 6.751447822998076
# Bought 1 XBT at price :+$6.15
# Sold 3.875723911499038 XBT at price :+$6.15   || Profit : 0.5813585867248571
# Bought 1 XBT at price :+$6.01
# Bought 1 XBT at price :+$6.01
# Sold 2.937861955749519 XBT at price :+$6.90   || Profit : 2.644075760174568
# Sold 1.4689309778747595 XBT at price :+$6.90   || Profit : 1.322037880087284
# Sold 0.7344654889373797 XBT at price :+$6.90   || Profit : 0.661018940043642
# Sold 0.36723274446868986 XBT at price :+$6.85   || Profit : 0.3158201602430731
# Sold 0.18361637223434493 XBT at price :+$6.55   || Profit : 0.10282516845123309
# Bought 1 XBT at price :+$6.95
# Sold 0.5918081861171725 XBT at price :+$6.95   || Profit : 0.5681358586724855
# Bought 1 XBT at price :+$6.30
# Bought 1 XBT at price :+$6.30
# Bought 1 XBT at price :+$6.28
# Bought 1 XBT at price :+$6.28
# Bought 1 XBT at price :+$6.77
# Sold 2.7959040930585863 XBT at price :+$6.79   || Profit : 2.2367232744468684
# Sold 1.3979520465292932 XBT at price :+$6.83   || Profit : 1.1742797190846062
# Bought 1 XBT at price :+$6.40
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.35
# Sold 2.1989760232646467 XBT at price :+$6.35   || Profit : 0.7916313683752716
# Sold 1.0994880116323233 XBT at price :+$6.35   || Profit : 0.36283104383866677
# Sold 0.5497440058161617 XBT at price :+$6.40   || Profit : -0.05497440058161597
# Sold 0.27487200290808084 XBT at price :+$6.50   || Profit : 0.0
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.50
# Bought 1 XBT at price :+$6.52
# Sold 1.6374360014540406 XBT at price :+$6.52   || Profit : 0.032748720029080115
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.50
# Sold 1.8187180007270203 XBT at price :+$6.50   || Profit : 0.0
# Sold 0.9093590003635101 XBT at price :+$6.55   || Profit : 0.04546795001817534
# Bought 1 XBT at price :+$6.55
# Bought 1 XBT at price :+$6.55
# Sold 1.4546795001817552 XBT at price :+$6.55   || Profit : 0.0727339750090875
# Sold 0.7273397500908776 XBT at price :+$6.55   || Profit : 0.40003686254998255
# Bought 1 XBT at price :+$6.55
# Bought 1 XBT at price :+$6.55
# Bought 1 XBT at price :+$6.55
# Sold 1.8636698750454388 XBT at price :+$6.55   || Profit : 1.025018431274991
# Sold 0.9318349375227194 XBT at price :+$6.26   || Profit : -0.7827413475190842
# Sold 0.4659174687613597 XBT at price :+$6.84   || Profit : 0.615011058764995
# Bought 1 XBT at price :+$6.84
# Bought 1 XBT at price :+$6.84
# Bought 1 XBT at price :+$6.84
# Bought 1 XBT at price :+$6.84
# Sold 2.23295873438068 XBT at price :+$6.85   || Profit : -0.3349438101571028
# Sold 1.11647936719034 XBT at price :+$6.86   || Profit : 0.7480411760175276
# Sold 0.55823968359517 XBT at price :+$6.85   || Profit : 0.36843819117281174
# Bought 1 XBT at price :+$6.09
# Bought 1 XBT at price :+$6.09
# Bought 1 XBT at price :+$6.09
# Sold 1.779119841797585 XBT at price :+$6.09   || Profit : 0.0
# Sold 0.8895599208987925 XBT at price :+$6.00   || Profit : -0.1334339881348192
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Bought 1 XBT at price :+$6.00
# Sold 2.944779960449396 XBT at price :+$6.00   || Profit : -0.029447799604493334
# Sold 1.472389980224698 XBT at price :+$6.31   || Profit : 0.44171699406740916
# Sold 0.736194990112349 XBT at price :+$6.31   || Profit : -0.4711647936719038
# Sold 0.3680974950561745 XBT at price :+$6.27   || Profit : -0.011042924851685327
# Bought 1 XBT at price :+$6.27
# Bought 1 XBT at price :+$6.27
# Bought 1 XBT at price :+$6.27
# Bought 1 XBT at price :+$6.27
# Sold 2.184048747528087 XBT at price :+$6.27   || Profit : -0.06552146242584315
# Bought 1 XBT at price :+$6.27
# Sold 1.5920243737640436 XBT at price :+$6.27   || Profit : -0.01592024373764151
# Bought 1 XBT at price :+$6.27
# Bought 1 XBT at price :+$6.14
# Sold 1.7960121868820218 XBT at price :+$6.03   || Profit : -0.44900304672050545
# Bought 1 XBT at price :+$5.00
# Bought 1 XBT at price :+$5.74
# Bought 1 XBT at price :+$5.74
# Sold 2.398006093441011 XBT at price :+$5.74   || Profit : -2.4699462762442397
# Sold 1.1990030467205055 XBT at price :+$5.74   || Profit : -0.7913420108355338
# Sold 0.5995015233602528 XBT at price :+$5.74   || Profit : -0.1558703960736656
# Sold 0.2997507616801264 XBT at price :+$5.74   || Profit : -0.18284796462487693
# Sold 0.1498753808400632 XBT at price :+$5.74   || Profit : -0.11390528943844799
# Sold 0.0749376904200316 XBT at price :+$5.74   || Profit : -0.056952644719223997
# Sold 0.0374688452100158 XBT at price :+$5.74   || Profit : -0.0292256992638123
# Bought 1 XBT at price :+$5.74
# Sold 0.5187344226050079 XBT at price :+$5.74   || Profit : -0.13487094987730194
# Sold 0.25936721130250395 XBT at price :+$5.74   || Profit : -0.19711908058990296
# Sold 0.12968360565125198 XBT at price :+$5.81   || Profit : -0.09596586818192648
# Sold 0.06484180282562599 XBT at price :+$5.81   || Profit : -0.04798293409096324
# Sold 0.032420901412812994 XBT at price :+$5.81   || Profit : -0.02399146704548162
# Sold 0.016210450706406497 XBT at price :+$5.81   || Profit : -0.01199573352274081
# Bought 1 XBT at price :+$5.83
# Bought 1 XBT at price :+$5.89
# Bought 1 XBT at price :+$5.50
# Bought 1 XBT at price :+$5.30
# Bought 1 XBT at price :+$5.58
# Sold 2.5081052253532032 XBT at price :+$5.58   || Profit : -2.4328620685926063
# Sold 1.2540526126766016 XBT at price :+$5.70   || Profit : -1.4296199784513255
# Sold 0.6270263063383008 XBT at price :+$5.58   || Profit : -0.7900531459862589
# Sold 0.3135131531691504 XBT at price :+$5.58   || Profit : -0.39502657299312943
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Bought 1 XBT at price :+$5.58
# Sold 5.156756576584575 XBT at price :+$5.85   || Profit : -5.105189010818731
# Sold 2.5783782882922877 XBT at price :+$6.17   || Profit : 0.2062702630633832
# INFO:tensorflow:Assets written to: model1/assets
# Total Profit :  2.3955825118560443

# %%
# For evaluating model
eval_stock = input("Enter Stock name")
model_name = input("Enter model name")
window_size = 10
data,init_xbt = get_stock_data(eval_stock)
init_xbt = init_xbt*0.01 # initial amount of coins (1%)
init_amt = int(input("Enter initial account balance ( > 100000 )"))
agent1 = Agent(window_size, model_name=model_name) # create an object of the class agent
profit,amt, xbt,_ = evaluate_model(agent1, data, window_size,init_xbt,init_amt) # predictiong from the model
show_eval_result(model_name, profit,amt,init_amt,xbt,init_xbt) # displaying summary
# Out:
# Enter Stock nametest
# Enter model namemodel1
# Enter initial account balance ( > 100000 )100000
# Bought 1 XBT at price :+$305.98
# Bought 1 XBT at price :+$305.94
# Sold 1.3 XBT at price :+$306.85   || Profit : +$1.18
# Sold 0.65 XBT at price :+$307.04   || Profit : +$0.69
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$309.50
# Bought 1 XBT at price :+$309.53
# Holding
# Bought 1 XBT at price :+$310.28
# Bought 1 XBT at price :+$310.21
# Holding
# Bought 1 XBT at price :+$308.28
# Bought 1 XBT at price :+$308.34
# Bought 1 XBT at price :+$309.27
# Holding
# Holding
# Bought 1 XBT at price :+$308.00
# Holding
# Bought 1 XBT at price :+$307.91
# Holding
# Bought 1 XBT at price :+$307.90
# Holding
# Holding
# Bought 1 XBT at price :+$307.22
# Bought 1 XBT at price :+$307.90
# Bought 1 XBT at price :+$307.89
# Bought 1 XBT at price :+$307.90
# Bought 1 XBT at price :+$307.98
# Bought 1 XBT at price :+$307.91
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$307.11
# Sold 8.825 XBT at price :+$307.98   || Profit : +$7.68
# Bought 1 XBT at price :+$307.92
# Sold 4.9125 XBT at price :+$307.99   || Profit : +$3.78
# Sold 2.45625 XBT at price :+$307.98   || Profit : +$0.22
# Sold 1.228125 XBT at price :+$309.19   || Profit : +$1.58
# Sold 0.6140625 XBT at price :+$309.19   || Profit : +$0.79
# Sold 0.30703125 XBT at price :+$309.59   || Profit : +$0.52
# Sold 0.153515625 XBT at price :+$309.59   || Profit : +$0.26
# Sold 0.0767578125 XBT at price :+$308.89   || Profit : +$0.08
# Bought 1 XBT at price :+$308.30
# Sold 0.53837890625 XBT at price :+$309.55   || Profit : +$0.88
# Sold 0.269189453125 XBT at price :+$310.60   || Profit : +$0.71
# Sold 0.1345947265625 XBT at price :+$310.50   || Profit : +$0.34
# Sold 0.06729736328125 XBT at price :+$310.23   || Profit : +$0.13
# Bought 1 XBT at price :+$309.21
# Bought 1 XBT at price :+$309.19
# Bought 1 XBT at price :+$309.49
# Sold 1.533648681640625 XBT at price :+$309.50   || Profit : +$1.84
# Holding
# Sold 0.7668243408203125 XBT at price :+$309.51   || Profit : +$0.90
# Bought 1 XBT at price :+$309.51
# Bought 1 XBT at price :+$309.44
# Bought 1 XBT at price :+$310.50
# Sold 1.8834121704101563 XBT at price :+$310.82   || Profit : +$3.07
# Sold 0.9417060852050781 XBT at price :+$310.50   || Profit : +$1.21
# Sold 0.4708530426025391 XBT at price :+$310.50   || Profit : +$0.58
# Sold 0.23542652130126954 XBT at price :+$310.77   || Profit : +$0.31
# Sold 0.11771326065063477 XBT at price :+$310.70   || Profit : +$0.14
# Sold 0.058856630325317384 XBT at price :+$310.70   || Profit : +$0.07
# Sold 0.029428315162658692 XBT at price :+$310.80   || Profit : +$0.04
# Sold 0.014714157581329346 XBT at price :+$312.89   || Profit : +$0.05
# Sold 0.007357078790664673 XBT at price :+$312.00   || Profit : +$0.01
# Holding
# Sold 0.0036785393953323365 XBT at price :+$311.64   || Profit : +$0.01
# Sold 0.0018392696976661683 XBT at price :+$311.71   || Profit : +$0.00
# Holding
# Holding
# Bought 1 XBT at price :+$312.00
# Bought 1 XBT at price :+$311.99
# Holding
# Bought 1 XBT at price :+$312.00
# Bought 1 XBT at price :+$311.99
# Sold 2.000919634848833 XBT at price :+$312.79   || Profit : +$1.60
# Sold 1.0004598174244166 XBT at price :+$312.79   || Profit : +$0.80
# Holding
# Sold 0.5002299087122083 XBT at price :+$313.35   || Profit : +$0.68
# Sold 0.25011495435610415 XBT at price :+$313.73   || Profit : +$0.43
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$315.48
# Bought 1 XBT at price :+$315.55
# Sold 1.1250574771780522 XBT at price :+$316.48   || Profit : +$1.13
# Sold 0.5625287385890261 XBT at price :+$316.40   || Profit : +$0.48
# Holding
# Bought 1 XBT at price :+$315.52
# Sold 0.781264369294513 XBT at price :+$316.27   || Profit : +$0.59
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$316.14
# Holding
# Bought 1 XBT at price :+$315.54
# Bought 1 XBT at price :+$315.52
# Holding
# Sold 1.8906321846472565 XBT at price :+$316.29   || Profit : +$1.46
# Sold 0.9453160923236282 XBT at price :+$316.29   || Profit : +$0.71
# Holding
# Bought 1 XBT at price :+$316.29
# Bought 1 XBT at price :+$316.28
# Sold 1.4726580461618142 XBT at price :+$316.28   || Profit : +$0.21
# Holding
# Holding
# Bought 1 XBT at price :+$315.52
# Holding
# Bought 1 XBT at price :+$315.52
# Bought 1 XBT at price :+$315.52
# Bought 1 XBT at price :+$316.27
# Bought 1 XBT at price :+$316.28
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$315.03
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$314.74
# Bought 1 XBT at price :+$314.74
# Bought 1 XBT at price :+$314.74
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.75
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.76
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.75
# Bought 1 XBT at price :+$314.75
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.65
# Bought 1 XBT at price :+$314.74
# Holding
# Bought 1 XBT at price :+$314.66
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$314.67
# Holding
# Bought 1 XBT at price :+$313.77
# Bought 1 XBT at price :+$314.67
# Bought 1 XBT at price :+$313.77
# Holding
# Bought 1 XBT at price :+$313.67
# Bought 1 XBT at price :+$313.50
# Bought 1 XBT at price :+$313.74
# Bought 1 XBT at price :+$314.77
# Holding
# Holding
# Bought 1 XBT at price :+$313.75
# Bought 1 XBT at price :+$314.66
# Sold 17.736329023080906 XBT at price :+$314.51   || Profit : +$17.91
# Holding
# Holding
# Bought 1 XBT at price :+$313.61
# Holding
# Holding
# Bought 1 XBT at price :+$313.51
# Holding
# Holding
# Bought 1 XBT at price :+$313.99
# Bought 1 XBT at price :+$313.98
# Sold 10.868164511540453 XBT at price :+$313.98   || Profit : +$5.11
# Sold 5.434082255770226 XBT at price :+$314.00   || Profit : +$2.12
# Sold 2.717041127885113 XBT at price :+$314.00   || Profit : +$0.90
# Sold 1.3585205639425566 XBT at price :+$314.39   || Profit : +$0.88
# Sold 0.6792602819712783 XBT at price :+$314.76   || Profit : +$0.69
# Sold 0.33963014098563915 XBT at price :+$314.76   || Profit : +$0.34
# Sold 0.16981507049281958 XBT at price :+$314.77   || Profit : +$0.17
# Sold 0.08490753524640979 XBT at price :+$314.67   || Profit : +$0.06
# Sold 0.042453767623204894 XBT at price :+$314.60   || Profit : +$0.03
# Sold 0.021226883811602447 XBT at price :+$314.70   || Profit : +$0.00
# Sold 0.010613441905801223 XBT at price :+$314.65   || Profit : -$0.00
# Sold 0.005306720952900612 XBT at price :+$314.64   || Profit : -$0.00
# Sold 0.002653360476450306 XBT at price :+$314.77   || Profit : +$0.00
# Holding
# Bought 1 XBT at price :+$314.77
# Holding
# Bought 1 XBT at price :+$313.77
# Bought 1 XBT at price :+$313.78
# Sold 1.501326680238225 XBT at price :+$316.20   || Profit : +$3.65
# Sold 0.7506633401191125 XBT at price :+$316.20   || Profit : +$1.82
# Sold 0.37533167005955625 XBT at price :+$315.79   || Profit : +$0.42
# Sold 0.18766583502977813 XBT at price :+$315.73   || Profit : +$0.20
# Bought 1 XBT at price :+$315.90
# Sold 0.5938329175148891 XBT at price :+$315.90   || Profit : +$0.73
# Holding
# Sold 0.29691645875744455 XBT at price :+$315.59   || Profit : +$0.27
# Bought 1 XBT at price :+$315.49
# Holding
# Bought 1 XBT at price :+$315.39
# Bought 1 XBT at price :+$315.92
# Bought 1 XBT at price :+$316.00
# Sold 2.148458229378722 XBT at price :+$316.88   || Profit : +$4.75
# Bought 1 XBT at price :+$316.27
# Holding
# Sold 1.574229114689361 XBT at price :+$316.27   || Profit : +$2.52
# Sold 0.7871145573446805 XBT at price :+$316.26   || Profit : +$1.25
# Sold 0.39355727867234025 XBT at price :+$316.69   || Profit : +$0.79
# Sold 0.19677863933617012 XBT at price :+$317.25   || Profit : +$0.51
# Holding
# Holding
# Bought 1 XBT at price :+$316.02
# Holding
# Sold 0.5983893196680851 XBT at price :+$317.19   || Profit : +$1.47
# Sold 0.29919465983404253 XBT at price :+$317.64   || Profit : +$0.87
# Holding
# Holding
# Bought 1 XBT at price :+$317.02
# Holding
# Holding
# Sold 0.6495973299170212 XBT at price :+$318.19   || Profit : +$2.24
# Sold 0.3247986649585106 XBT at price :+$318.07   || Profit : +$1.08
# Sold 0.1623993324792553 XBT at price :+$317.28   || Profit : +$0.41
# Bought 1 XBT at price :+$318.16
# Bought 1 XBT at price :+$318.19
# Holding
# Sold 1.0811996662396277 XBT at price :+$318.14   || Profit : +$3.67
# Bought 1 XBT at price :+$317.16
# Bought 1 XBT at price :+$318.37
# Bought 1 XBT at price :+$318.24
# Holding
# Holding
# Bought 1 XBT at price :+$316.89
# Bought 1 XBT at price :+$318.37
# Bought 1 XBT at price :+$318.60
# Holding
# Holding
# Bought 1 XBT at price :+$317.30
# Holding
# Sold 4.040599833119813 XBT at price :+$318.61   || Profit : +$15.60
# Sold 2.0202999165599067 XBT at price :+$318.48   || Profit : +$7.52
# Holding
# Holding
# Bought 1 XBT at price :+$318.87
# Sold 1.5101499582799534 XBT at price :+$318.40   || Profit : +$5.48
# Sold 0.7550749791399767 XBT at price :+$318.22   || Profit : +$2.61
# Holding
# Bought 1 XBT at price :+$317.78
# Bought 1 XBT at price :+$317.73
# Holding
# Holding
# Bought 1 XBT at price :+$317.73
# Bought 1 XBT at price :+$317.73
# Bought 1 XBT at price :+$317.73
# Bought 1 XBT at price :+$317.73
# Holding
# Sold 3.3775374895699883 XBT at price :+$317.86   || Profit : +$9.56
# Bought 1 XBT at price :+$317.86
# Bought 1 XBT at price :+$317.86
# Bought 1 XBT at price :+$317.86
# Bought 1 XBT at price :+$317.86
# Bought 1 XBT at price :+$317.86
# Holding
# Bought 1 XBT at price :+$317.10
# Bought 1 XBT at price :+$318.57
# Holding
# Holding
# Sold 5.188768744784994 XBT at price :+$318.90   || Profit : +$18.21
# Bought 1 XBT at price :+$318.90
# Holding
# Sold 3.094384372392497 XBT at price :+$318.90   || Profit : +$10.55
# Holding
# Holding
# Bought 1 XBT at price :+$319.68
# Sold 2.0471921861962485 XBT at price :+$319.73   || Profit : +$8.62
# Holding
# Sold 1.0235960930981243 XBT at price :+$321.20   || Profit : +$5.81
# Bought 1 XBT at price :+$321.05
# Holding
# Bought 1 XBT at price :+$320.15
# Bought 1 XBT at price :+$319.77
# Holding
# Holding
# Bought 1 XBT at price :+$320.27
# Holding
# Holding
# Bought 1 XBT at price :+$320.07
# Holding
# Bought 1 XBT at price :+$319.94
# Bought 1 XBT at price :+$319.77
# Bought 1 XBT at price :+$320.26
# Holding
# Bought 1 XBT at price :+$320.00
# Holding
# Holding
# Bought 1 XBT at price :+$320.15
# Bought 1 XBT at price :+$320.00
# Bought 1 XBT at price :+$320.00
# Bought 1 XBT at price :+$320.15
# Holding
# Bought 1 XBT at price :+$320.00
# Bought 1 XBT at price :+$320.00
# Bought 1 XBT at price :+$320.00
# Holding
# Bought 1 XBT at price :+$320.26
# Bought 1 XBT at price :+$320.13
# Holding
# Bought 1 XBT at price :+$319.95
# Bought 1 XBT at price :+$319.80
# Bought 1 XBT at price :+$319.65
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$319.72
# Holding
# Holding
# Bought 1 XBT at price :+$319.32
# Bought 1 XBT at price :+$319.85
# Holding
# Bought 1 XBT at price :+$319.71
# Holding
# Holding
# Bought 1 XBT at price :+$319.73
# Holding
# Holding
# Bought 1 XBT at price :+$319.00
# Bought 1 XBT at price :+$319.67
# Sold 14.511798046549062 XBT at price :+$320.38   || Profit : +$70.53
# Sold 7.255899023274531 XBT at price :+$320.22   || Profit : +$31.35
# Sold 3.6279495116372655 XBT at price :+$320.08   || Profit : +$15.09
# Bought 1 XBT at price :+$320.22
# Holding
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$320.20
# Sold 2.8139747558186325 XBT at price :+$320.49   || Profit : +$12.63
# Holding
# Holding
# Bought 1 XBT at price :+$320.40
# Holding
# Holding
# Bought 1 XBT at price :+$319.40
# Bought 1 XBT at price :+$319.50
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$319.43
# Bought 1 XBT at price :+$320.51
# Bought 1 XBT at price :+$320.04
# Holding
# Bought 1 XBT at price :+$319.00
# Bought 1 XBT at price :+$319.13
# Bought 1 XBT at price :+$319.02
# Sold 5.906987377909316 XBT at price :+$319.00   || Profit : +$17.60
# Bought 1 XBT at price :+$319.15
# Bought 1 XBT at price :+$319.15
# Holding
# Bought 1 XBT at price :+$319.00
# Bought 1 XBT at price :+$319.03
# Bought 1 XBT at price :+$319.36
# Holding
# Bought 1 XBT at price :+$319.46
# Bought 1 XBT at price :+$319.47
# Holding
# Bought 1 XBT at price :+$318.92
# Bought 1 XBT at price :+$318.92
# Bought 1 XBT at price :+$318.92
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$317.76
# Bought 1 XBT at price :+$319.46
# Bought 1 XBT at price :+$319.46
# Sold 9.453493688954659 XBT at price :+$319.46   || Profit : +$30.16
# Sold 4.726746844477329 XBT at price :+$319.40   || Profit : +$14.79
# Bought 1 XBT at price :+$319.48
# Holding
# Sold 2.8633734222386646 XBT at price :+$319.40   || Profit : +$8.93
# Sold 1.4316867111193323 XBT at price :+$319.46   || Profit : +$4.55
# Sold 0.7158433555596662 XBT at price :+$319.45   || Profit : +$2.26
# Holding
# Holding
# Bought 1 XBT at price :+$319.40
# Bought 1 XBT at price :+$317.80
# Holding
# Bought 1 XBT at price :+$318.98
# Holding
# Bought 1 XBT at price :+$318.98
# Bought 1 XBT at price :+$318.89
# Bought 1 XBT at price :+$318.85
# Holding
# Bought 1 XBT at price :+$317.57
# Holding
# Sold 3.8579216777798333 XBT at price :+$318.85   || Profit : +$7.56
# Bought 1 XBT at price :+$318.85
# Holding
# Holding
# Bought 1 XBT at price :+$317.37
# Bought 1 XBT at price :+$317.50
# Holding
# Sold 3.4289608388899167 XBT at price :+$317.49   || Profit : +$1.61
# Holding
# Holding
# Bought 1 XBT at price :+$317.40
# Bought 1 XBT at price :+$317.49
# Holding
# Bought 1 XBT at price :+$317.49
# Bought 1 XBT at price :+$317.49
# Holding
# Bought 1 XBT at price :+$317.20
# Bought 1 XBT at price :+$317.48
# Bought 1 XBT at price :+$317.32
# Holding
# Bought 1 XBT at price :+$317.17
# Bought 1 XBT at price :+$317.12
# Holding
# Holding
# Bought 1 XBT at price :+$314.01
# Bought 1 XBT at price :+$314.94
# Bought 1 XBT at price :+$314.81
# Holding
# Holding
# Bought 1 XBT at price :+$314.26
# Bought 1 XBT at price :+$314.26
# Bought 1 XBT at price :+$315.68
# Bought 1 XBT at price :+$315.67
# Holding
# Bought 1 XBT at price :+$314.56
# Sold 10.214480419444959 XBT at price :+$315.69   || Profit : +$17.16
# Bought 1 XBT at price :+$315.68
# Sold 5.607240209722479 XBT at price :+$315.69   || Profit : +$8.02
# Sold 2.8036201048612397 XBT at price :+$315.69   || Profit : +$4.01
# Sold 1.4018100524306198 XBT at price :+$315.68   || Profit : +$1.57
# Bought 1 XBT at price :+$315.69
# Bought 1 XBT at price :+$316.70
# Sold 1.70090502621531 XBT at price :+$316.80   || Profit : +$3.38
# Holding
# Sold 0.850452513107655 XBT at price :+$317.53   || Profit : +$2.20
# Sold 0.4252262565538275 XBT at price :+$317.50   || Profit : +$0.78
# Sold 0.21261312827691375 XBT at price :+$317.47   || Profit : +$0.38
# Sold 0.10630656413845688 XBT at price :+$317.60   || Profit : +$0.20
# Bought 1 XBT at price :+$316.59
# Holding
# Bought 1 XBT at price :+$316.75
# Sold 1.0531532820692284 XBT at price :+$317.53   || Profit : +$1.94
# Sold 0.5265766410346142 XBT at price :+$317.53   || Profit : +$0.49
# Holding
# Holding
# Bought 1 XBT at price :+$317.19
# Holding
# Holding
# Bought 1 XBT at price :+$316.00
# Bought 1 XBT at price :+$314.90
# Holding
# Bought 1 XBT at price :+$314.81
# Bought 1 XBT at price :+$315.99
# Bought 1 XBT at price :+$315.97
# Bought 1 XBT at price :+$315.97
# Holding
# Bought 1 XBT at price :+$314.77
# Bought 1 XBT at price :+$315.73
# Holding
# Holding
# Bought 1 XBT at price :+$315.91
# Holding
# Holding
# Bought 1 XBT at price :+$311.97
# Bought 1 XBT at price :+$311.96
# Holding
# Bought 1 XBT at price :+$313.40
# Bought 1 XBT at price :+$314.14
# Holding
# Bought 1 XBT at price :+$312.76
# Bought 1 XBT at price :+$312.76
# Holding
# Holding
# Sold 8.263288320517308 XBT at price :+$312.77   || Profit : +$6.69
# Holding
# Holding
# Bought 1 XBT at price :+$312.76
# Holding
# Bought 1 XBT at price :+$312.54
# Bought 1 XBT at price :+$312.54
# Holding
# Holding
# Bought 1 XBT at price :+$311.92
# Holding
# Bought 1 XBT at price :+$311.94
# Bought 1 XBT at price :+$311.94
# Holding
# Holding
# Bought 1 XBT at price :+$311.93
# Bought 1 XBT at price :+$311.93
# Holding
# Holding
# Bought 1 XBT at price :+$311.00
# Bought 1 XBT at price :+$311.00
# Holding
# Bought 1 XBT at price :+$311.00
# Holding
# Bought 1 XBT at price :+$311.92
# Bought 1 XBT at price :+$311.94
# Sold 10.631644160258654 XBT at price :+$312.41   || Profit : +$14.99
# Sold 5.315822080129327 XBT at price :+$313.98   || Profit : +$15.84
# Sold 2.6579110400646635 XBT at price :+$312.56   || Profit : +$4.15
# Sold 1.3289555200323317 XBT at price :+$314.07   || Profit : +$2.86
# Sold 0.6644777600161659 XBT at price :+$313.89   || Profit : +$1.31
# Sold 0.33223888000808294 XBT at price :+$313.92   || Profit : +$0.66
# Holding
# Holding
# Bought 1 XBT at price :+$312.32
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$312.85
# Bought 1 XBT at price :+$311.96
# Bought 1 XBT at price :+$312.84
# Bought 1 XBT at price :+$312.84
# Holding
# Bought 1 XBT at price :+$312.31
# Bought 1 XBT at price :+$312.33
# Bought 1 XBT at price :+$312.33
# Holding
# Holding
# Holding
# Sold 4.166119440004041 XBT at price :+$313.97   || Profit : +$8.50
# Sold 2.0830597200020207 XBT at price :+$313.96   || Profit : +$4.21
# Holding
# Bought 1 XBT at price :+$313.04
# Bought 1 XBT at price :+$313.03
# Holding
# Sold 2.0415298600010106 XBT at price :+$313.03   || Profit : +$2.23
# Sold 1.0207649300005053 XBT at price :+$313.78   || Profit : +$1.88
# Bought 1 XBT at price :+$312.36
# Bought 1 XBT at price :+$313.78
# Bought 1 XBT at price :+$313.90
# Holding
# Holding
# Sold 2.0103824650002524 XBT at price :+$314.06   || Profit : +$4.22
# Bought 1 XBT at price :+$312.25
# Holding
# Bought 1 XBT at price :+$312.25
# Holding
# Holding
# Bought 1 XBT at price :+$313.97
# Bought 1 XBT at price :+$312.25
# Holding
# Bought 1 XBT at price :+$313.93
# Bought 1 XBT at price :+$312.28
# Bought 1 XBT at price :+$313.80
# Bought 1 XBT at price :+$313.94
# Holding
# Holding
# Bought 1 XBT at price :+$314.00
# Holding
# Holding
# Bought 1 XBT at price :+$312.31
# Sold 6.005191232500126 XBT at price :+$313.89   || Profit : +$11.53
# Sold 3.002595616250063 XBT at price :+$313.94   || Profit : +$5.07
# Holding
# Bought 1 XBT at price :+$313.79
# Bought 1 XBT at price :+$313.80
# Holding
# Holding
# Holding
# Sold 2.5012978081250314 XBT at price :+$313.69   || Profit : +$3.60
# Sold 1.2506489040625157 XBT at price :+$313.69   || Profit : +$1.80
# Holding
# Bought 1 XBT at price :+$313.69
# Bought 1 XBT at price :+$313.69
# Holding
# Bought 1 XBT at price :+$313.69
# Holding
# Sold 2.1253244520312577 XBT at price :+$313.69   || Profit : +$3.00
# Holding
# Holding
# Bought 1 XBT at price :+$313.68
# Bought 1 XBT at price :+$313.66
# Holding
# Holding
# Holding
# Bought 1 XBT at price :+$313.00
# Bought 1 XBT at price :+$312.69
# Holding
# Holding
# Bought 1 XBT at price :+$312.49
# Bought 1 XBT at price :+$312.69
# Holding
# Bought 1 XBT at price :+$312.62
# Bought 1 XBT at price :+$313.27
# Holding
# Holding
# Bought 1 XBT at price :+$311.43
# Bought 1 XBT at price :+$311.43
# Holding
# Bought 1 XBT at price :+$311.97
# Holding
# Holding
# Bought 1 XBT at price :+$311.18
# Holding
# Bought 1 XBT at price :+$311.15
# Holding
# Holding
# Sold 7.562662226015629 XBT at price :+$311.49   || Profit : +$2.57
# Holding
# Holding
# Bought 1 XBT at price :+$311.20
# Bought 1 XBT at price :+$311.50
# Bought 1 XBT at price :+$311.50
# Sold 5.281331113007814 XBT at price :+$311.50   || Profit : +$1.69
# Bought 1 XBT at price :+$311.50
# Bought 1 XBT at price :+$311.19
# Bought 1 XBT at price :+$311.99
# Bought 1 XBT at price :+$311.99
# Holding
# Holding
# Bought 1 XBT at price :+$311.21
# Bought 1 XBT at price :+$311.94
# Bought 1 XBT at price :+$311.99
# Sold 6.140665556503907 XBT at price :+$313.60   || Profit : +$14.80
# Bought 1 XBT at price :+$312.02
# Sold 3.5703327782519536 XBT at price :+$313.49   || Profit : +$8.18
# Bought 1 XBT at price :+$313.49
# Holding
# Bought 1 XBT at price :+$312.05
# Sold 2.785166389125977 XBT at price :+$313.49   || Profit : +$6.35
# Bought 1 XBT at price :+$313.49
# Holding
# Bought 1 XBT at price :+$312.16
# Holding
# Bought 1 XBT at price :+$313.49
# Holding
# Holding
# Sold 2.8925831945629885 XBT at price :+$314.30   || Profit : +$8.30
# Sold 1.4462915972814943 XBT at price :+$315.00   || Profit : +$5.16
# Holding
# Bought 1 XBT at price :+$313.22
# Holding
# Holding
# Holding
# Sold 1.223145798640747 XBT at price :+$314.25   || Profit : +$3.36
# Bought 1 XBT at price :+$313.42
# Holding
# Bought 1 XBT at price :+$313.19
# Bought 1 XBT at price :+$313.02
# Holding
# Bought 1 XBT at price :+$313.83
# Bought 1 XBT at price :+$314.25
# Holding
# Bought 1 XBT at price :+$313.02
# Sold 3.6115728993203735 XBT at price :+$314.40   || Profit : +$10.47
# Bought 1 XBT at price :+$313.47
# Holding
# Bought 1 XBT at price :+$313.10
# Bought 1 XBT at price :+$314.38
# Holding
# Bought 1 XBT at price :+$313.74
# Sold 3.8057864496601868 XBT at price :+$315.09   || Profit : +$13.66
# Sold 1.9028932248300934 XBT at price :+$315.10   || Profit : +$6.01
# Sold 0.9514466124150467 XBT at price :+$315.83   || Profit : +$3.67
# Bought 1 XBT at price :+$314.51
# Holding
# Sold 0.9757233062075233 XBT at price :+$315.26   || Profit : +$3.19
# Sold 0.48786165310376167 XBT at price :+$315.26   || Profit : +$1.60
# Sold 0.24393082655188084 XBT at price :+$315.27   || Profit : +$0.80
# Sold 0.12196541327594042 XBT at price :+$315.81   || Profit : +$0.46
# Sold 0.06098270663797021 XBT at price :+$315.88   || Profit : +$0.23
#
# SUMMARY:
# Initial Bank Balance: +$100000.00
# Initial Bitcoins owned(1%): 0.6
#
#
# Final Bank Balace: +$100229.99
# Final Bitcoins owned: 0.06098270663797021
#
# Total Profit: +$614.20
# (Trained Model  :model1)

# %%
# Download Trained model zip

#!zip -r /content/file.zip /content/Folder_To_Zip
#from google.colab import files
#files.download("/content/file.zip")

# %%
# Unzip model
#!unzip compressed_file_name.zip
